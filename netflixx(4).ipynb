# %% [markdown]
# # ***NETFLIX DATA ANALYSIS***

# %% [markdown]
# ## PROBLEM STATEMENT

# %% [markdown]
# With the rapid expansion of digital streaming platforms,Netflix has developed a vast library of movies and TV shows across different countries,types and durations.However,understanding the patterns within this large datset is essential to identify trends in content production,audience targetting and platform growth.
#
# This project aims to analyse tghe Netflix dataset to explore the distribution and characteristics of content available in the platform.The study focuses on identifying patterns in content type(Movies and TV shows),release trends over the years,country-wise contributions,ratings,classification and duration

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# - Data collected from kaggle
#
# - The dataset used in this project is the Netflix  Dataset. It contains information about movies and TV shows on Netflix.
#
# - There are about 8,807 records in the dataset. It includes details like title, type, director, cast, country, release year, rating, duration, and genre.
#
# - Some data was missing, so it was cleaned. The duration column was also corrected. Movies are measured in minutes, and TV shows are measured in seasons.
#
# - This dataset helps us understand Netflix content, such as popular genres, release trends, and audience types. It is useful for learning data analysis.

# %% [markdown]
# ## Aim of the Analysis

# %% [markdown]
# The aim of this project is to understand Netflix content. It helps to analyze movies and TV shows, find popular genres, study release year trends, and understand audience ratings. It is mainly used to learn data analysis and visualization.

# %% [markdown]
# # DAY 1

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading dataset

# %%
df=pd.read_csv("netflix-titles.csv")
print(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Inspect data

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.sample()
# Out:
#      show_id   type        title     director  \
# 5630   s5631  Movie  Take the 10  Chester Tam
#
#                                                    cast        country  \
# 5630  Josh Peck, Tony Revolori, Kevin Corrigan, Ches...  United States
#
#             date_added  release_year rating duration listed_in  \
# 5630  January 20, 2017          2017  TV-MA   80 min  Comedies
#
#                                             description
# 5630  Two buddies working dead-end cashier jobs endu...

# %%
df.dtypes #check the columns data type
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.columns #display columns names
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.shape #display no.of rows and columns
# Out:
# (8807, 12)

# %% [markdown]
# ## Information of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# - Total entries:8807 entries ,0 to 8806
# - Data columns = 12
# - Memory usage = 825.8+ kb
# - MISSING VALUES :
# - Director = 2634
# - Cast = 825
# - Country = 831
# - Date_added = 10
# - Rating = 4
# - Duration = 3
# - Data type mistakes
# - (Duration) = Duration is integer , not object

# %% [markdown]
# # Selecting coloumns

# %% [markdown]
# ## Single coloumn

# %%
df['cast']
# Out:
# 0                                                     NaN
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                     NaN
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                  NaN
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object

# %% [markdown]
# ## Multiple columns

# %%
newdf=df[['rating','duration']]
print(newdf)
# Out:
#      rating   duration
# 0     PG-13     90 min
# 1     TV-MA  2 Seasons
# 2     TV-MA   1 Season
# 3     TV-MA   1 Season
# 4     TV-MA  2 Seasons
# ...     ...        ...
# 8802      R    158 min
# 8803  TV-Y7  2 Seasons
# 8804      R     88 min
# 8805     PG     88 min
# 8806  TV-14    111 min
#
# [8807 rows x 2 columns]

# %%
newdf[['rating','duration']].head()
# Out:
#   rating   duration
# 0  PG-13     90 min
# 1  TV-MA  2 Seasons
# 2  TV-MA   1 Season
# 3  TV-MA   1 Season
# 4  TV-MA  2 Seasons

# %% [markdown]
# # DAY 2

# %% [markdown]
# # Filter the data

# %%
df[df['release_year']<2015]
# Out:
#      show_id     type               title         director  \
# 7         s8    Movie             Sankofa     Haile Gerima
# 22       s23    Movie     Avvai Shanmughi   K.S. Ravikumar
# 24       s25    Movie               Jeans       S. Shankar
# 26       s27    Movie      Minsara Kanavu      Rajiv Menon
# 27       s28    Movie           Grown Ups     Dennis Dugan
# ...      ...      ...                 ...              ...
# 8799   s8800    Movie               Zenda   Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8802   s8803    Movie              Zodiac    David Fincher
# 8804   s8805    Movie          Zombieland  Ruben Fleischer
# 8805   s8806    Movie                Zoom     Peter Hewitt
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %%
df[df['type']=='TV Show']
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df[df['country']=='India']
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
df[df['listed_in']=="Kids' TV"]
# Out:
#      show_id     type                    title director  \
# 34       s35  TV Show  Tayo and Little Wizards      NaN
# 39       s40  TV Show             Chhota Bheem      NaN
# 65       s66  TV Show             Numberblocks      NaN
# 89       s90  TV Show              Mighty Raju      NaN
# 100     s101  TV Show  Tobot Galaxy Detectives      NaN
# ...      ...      ...                      ...      ...
# 8669   s8670  TV Show            V.R. Troopers      NaN
# 8679   s8680  TV Show       ViR: The Robot Boy      NaN
# 8783   s8784  TV Show                     Yoko      NaN
# 8785   s8786  TV Show                      YOM      NaN
# 8797   s8798  TV Show                Zak Storm      NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# 65    Beth Chalmers, David Holt, Marcel McCalla, Ter...
# 89    Julie Tejwani, Sabina Malik, Jigna Bhardwaj, R...
# ...

# %%
df[df['title']=='Chhota Bheem']
# Out:
#    show_id     type         title director  \
# 39     s40  TV Show  Chhota Bheem      NaN
#
#                                                  cast country  \
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
#
#             date_added  release_year rating   duration listed_in  \
# 39  September 16, 2021          2021  TV-Y7  3 Seasons  Kids' TV
#
#                                           description
# 39  A brave, energetic little boy with superhuman ...

# %% [markdown]
# ## Filtering with Multiple Conditions

# %%
df[(df['type']=='TV Show')&(df['country']=='India')]
# Out:
#      show_id     type                               title director  \
# 4         s5  TV Show                        Kota Factory      NaN
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %% [markdown]
# ## Selecting rows

# %%
df.iloc[9] #single row
df.iloc[5:12] #portion
# Out:
#    show_id     type                                title  \
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 7       s8    Movie                              Sankofa
# 8       s9  TV Show        The Great British Baking Show
# 9      s10    Movie                         The Starling
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                     Bangkok Breaking
#
#                          director  \
# 5                   Mike Flanagan
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 8                 Andy Devonshire
# 9                  Theodore Melfi
# 10                            NaN
# 11              Kongkiat Komesiri
#
#                                                  cast  \
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# ...

# %% [markdown]
# # loc method

# %%
df.loc[1000,'title']
# Out:
# 'Wild Dog'

# %% [markdown]
# # Rename column

# %%
df.rename(columns={"rating":"category"},inplace=True)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year category   duration  \
# 0  September 25, 2021          2020    PG-13     90 min
# 1  September 24, 2021          2021    TV-MA  2 Seasons
# ...

# %% [markdown]
# - The heading rating changes to category

# %% [markdown]
# # Counts

# %%
df['country'].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# # DAY 3

# %% [markdown]
# # Data Cleaning

# %%
#Remove text units and convert to numbers
# df['duration']=pd.to_numeric(
#    df['duration']
#    .astype(str)
#    .str.replace(r'[^0-9.-]','',regex=true)
#    .replace('',none)'
#    errors='coerce'
## THE CODE IS NOT WORK IN THE DATASET.DURATION'S UNIT IS DIFFERENT

# %%
#Parse date_added as datetime
df["date_added"] = pd.to_datetime(df["date_added"],errors='coerce')
#df["hour"] = df["date_added"].dt.hour
#df["month"] =df["date_added"].dt.month
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   category      8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
df['category'].value_counts()
# Out:
# category
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year category   duration  \
# 0 2021-09-25          2020    PG-13     90 min
# 1 2021-09-24          2021    TV-MA  2 Seasons
# 2 2021-09-24          2021    TV-MA   1 Season
# ...

# %% [markdown]
# ## Categorising rating column into five

# %%
category = {
    #Kids
    'TV-Y'     : 'Kids',
    'TV-Y7'    : 'Kids',
    'TV-Y7-FV' : 'Kids',
    'G'        : 'Kids',
    #Greneral
    'TV-G'     : 'General',
    'PG'       : 'General',
    #Teen
    'TV-PG'    : 'Teen',
    'TV-14'    : 'Teen',
    'PG-13'    : 'Teen',
    #Adult
    'TV-MA'    : 'Adult',
    'R'        : 'Adult',
    'NC-17'    : 'Adult',
    #Unknown
    'NR'       :'Unknown',
    'UR'       :'Unknown',
}
df['category'] = df['category'].map(category)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year category   duration  \
# 0 2021-09-25          2020     Teen     90 min
# 1 2021-09-24          2021    Adult  2 Seasons
# 2 2021-09-24          2021    Adult   1 Season
# ...

# %% [markdown]
# ## Handling missing values

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# category           7
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#How fill missing values
#numerical - fill with median 
#categorical -fill with mode

# %%
df['release_year'].mode()
# Out:
# 0    2018
# Name: release_year, dtype: int64

# %%
df['director'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12552\4009837435.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna('Unknown',inplace=True)

# %%
df['country'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12552\141793252.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna('Unknown',inplace=True)

# %%
df['cast'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12552\2343259098.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna('Unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# category         7
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df.dropna(subset=['date_added','category','duration'],inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# category        0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.shape
# Out:
# (8790, 12)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Handling Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Data cleaning completed

# %% [markdown]
# ## Ensuring data cleaned

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year category   duration  \
# 0 2021-09-25          2020     Teen     90 min
# 1 2021-09-24          2021    Adult  2 Seasons
# 2 2021-09-24          2021    Adult   1 Season
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb          Unknown
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                            Unknown        Unknown
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year category   duration  \
# 8802 2019-11-20          2007    Adult    158 min
# 8803 2019-07-01          2018     Kids  2 Seasons
# 8804 2019-11-01          2009    Adult     88 min
# ...

# %%
df.shape
# Out:
# (8790, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   cast          8790 non-null   object
#  5   country       8790 non-null   object
#  6   date_added    8790 non-null   datetime64[ns]
#  7   release_year  8790 non-null   int64
#  8   category      8790 non-null   object
#  9   duration      8790 non-null   object
#  10  listed_in     8790 non-null   object
#  11  description   8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 892.7+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'category', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Create two data sets : TV SHOW and MOVIE

# %% [markdown]
# ## TV Show

# %%
TV=df[df['type']=='TV Show']
TV
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797  TV Show             Yunus Emre          Unknown
# 8797   s8798  TV Show              Zak Storm          Unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          Unknown
# 8803   s8804  TV Show            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
TV=TV.drop(columns=["type"])

# %%
TV
# Out:
#      show_id                  title         director  \
# 1         s2          Blood & Water          Unknown
# 2         s3              Ganglands  Julien Leclercq
# 3         s4  Jailbirds New Orleans          Unknown
# 4         s5           Kota Factory          Unknown
# 5         s6          Midnight Mass    Mike Flanagan
# ...      ...                    ...              ...
# 8795   s8796        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797             Yunus Emre          Unknown
# 8797   s8798              Zak Storm          Unknown
# 8800   s8801     Zindagi Gulzar Hai          Unknown
# 8803   s8804            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                               Unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...

# %% [markdown]
# ## Correcting data type of duration column in TV

# %%
TV["duration"] =TV["duration"].astype(str)
TV["duration"] =TV["duration"].str.split().str[0].astype(int)

# %%
TV
# Out:
# <bound method DataFrame.drop of      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797  TV Show             Yunus Emre          Unknown
# 8797   s8798  TV Show              Zak Storm          Unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          Unknown
# 8803   s8804  TV Show            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# ## Movies

# %%
movie=df[df['type']=='Movie']
movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
movie.drop(columns=['type'],inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12552\2520571185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie.drop(columns=['type'],inplace=True)

# %%
movie
# Out:
#      show_id                             title                       director  \
# 0         s1              Dick Johnson Is Dead                Kirsten Johnson
# 6         s7  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7         s8                           Sankofa                   Haile Gerima
# 9        s10                      The Starling                 Theodore Melfi
# 12       s13                      Je Suis Karl            Christian Schwochow
# ...      ...                               ...                            ...
# 8801   s8802                           Zinzana                Majid Al Ansari
# 8802   s8803                            Zodiac                  David Fincher
# 8804   s8805                        Zombieland                Ruben Fleischer
# 8805   s8806                              Zoom                   Peter Hewitt
# 8806   s8807                            Zubaan                    Mozez Singh
#
# ...

# %% [markdown]
# ## Correcting data type of duration column in Movie

# %%
movie["duration"]=movie["duration"].str.replace("min"," ",regex=False) 
movie["duration"]=pd.to_numeric(movie["duration"],errors="coerce")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12552\1063813615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie["duration"]=movie["duration"].str.replace("min"," ",regex=False)
# C:\Users\hp\AppData\Local\Temp\ipykernel_12552\1063813615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie["duration"]=pd.to_numeric(movie["duration"],errors="coerce")

# %%
movie
# Out:
#      show_id                             title                       director  \
# 0         s1              Dick Johnson Is Dead                Kirsten Johnson
# 6         s7  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7         s8                           Sankofa                   Haile Gerima
# 9        s10                      The Starling                 Theodore Melfi
# 12       s13                      Je Suis Karl            Christian Schwochow
# ...      ...                               ...                            ...
# 8801   s8802                           Zinzana                Majid Al Ansari
# 8802   s8803                            Zodiac                  David Fincher
# 8804   s8805                        Zombieland                Ruben Fleischer
# 8805   s8806                              Zoom                   Peter Hewitt
# 8806   s8807                            Zubaan                    Mozez Singh
#
# ...

# %% [markdown]
# ## Save the Netflix new csv file

# %%
df.to_csv('netflix_cleaned.csv',index=False)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
movie.to_csv('movie_numerical.csv',index=False)

# %%
movie
# Out:
#      show_id                             title                       director  \
# 0         s1              Dick Johnson Is Dead                Kirsten Johnson
# 6         s7  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7         s8                           Sankofa                   Haile Gerima
# 9        s10                      The Starling                 Theodore Melfi
# 12       s13                      Je Suis Karl            Christian Schwochow
# ...      ...                               ...                            ...
# 8801   s8802                           Zinzana                Majid Al Ansari
# 8802   s8803                            Zodiac                  David Fincher
# 8804   s8805                        Zombieland                Ruben Fleischer
# 8805   s8806                              Zoom                   Peter Hewitt
# 8806   s8807                            Zubaan                    Mozez Singh
#
# ...

# %%
TV.to_csv('TV_numerical.csv',index=False)

# %%
TV
# Out:
#      show_id                  title         director  \
# 1         s2          Blood & Water          Unknown
# 2         s3              Ganglands  Julien Leclercq
# 3         s4  Jailbirds New Orleans          Unknown
# 4         s5           Kota Factory          Unknown
# 5         s6          Midnight Mass    Mike Flanagan
# ...      ...                    ...              ...
# 8795   s8796        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797             Yunus Emre          Unknown
# 8797   s8798              Zak Storm          Unknown
# 8800   s8801     Zindagi Gulzar Hai          Unknown
# 8803   s8804            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                               Unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...

# %%
df_new = pd.read_csv('netflix_cleaned.csv')
df_new
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          Unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # DAY 4

# %% [markdown]
# # Summary statistics

# %%
df_new.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'category', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ## Average(mean)

# %%
print('release_year :',df_new['release_year'].mean())
# Out:
# release_year : 2014.183162684869

# %% [markdown]
# ## Median

# %%
print('release_year :',df_new['release_year'].median())
# Out:
# release_year : 2017.0

# %% [markdown]
# ## Mode

# %%
print('release_year :',df_new['release_year'].mode())
# Out:
# release_year : 0    2018
# Name: release_year, dtype: int64

# %%
df_new.select_dtypes(include='object').mode()
# Out:
#      show_id   type                          title director     cast  \
# 0         s1  Movie                         #Alive  Unknown  Unknown
# 1        s10    NaN  #AnneFrank - Parallel Stories      NaN      NaN
# 2       s100    NaN              #FriendButMarried      NaN      NaN
# 3      s1000    NaN            #FriendButMarried 2      NaN      NaN
# 4      s1001    NaN                          #Roxy      NaN      NaN
# ...      ...    ...                            ...      ...      ...
# 8785    s995    NaN                       忍者ハットリくん      NaN      NaN
# 8786    s996    NaN                           海的儿子      NaN      NaN
# 8787    s997    NaN                           마녀사냥      NaN      NaN
# 8788    s998    NaN                        반드시 잡는다      NaN      NaN
# 8789    s999    NaN            최강전사 미니특공대 : 영웅의 탄생      NaN      NaN
#
#             country  date_added category  duration  \
# 0     United States  2020-01-01    Adult  1 Season
# ...

# %% [markdown]
# ## STD

# %%
df_new.select_dtypes(include='number').std()
# Out:
# release_year    8.825466
# dtype: float64

# %% [markdown]
# ## Describe

# %%
df_new.describe()

# %% [markdown]
# - min year : 1925
# - max year : 2025
# - 25% upper data started from year 2013
# - 50% upper data started from year 2017
# - 75% upper data started from year 2019
# - mean : 2014.18
# - median : 2017
# - std : 8.81

# %%
df_new.describe(include=object)
# Out:
#        show_id   type                 title director     cast        country  \
# count     8790   8790                  8790     8790     8790           8790
# unique    8790      2                  8790     4527     7679            749
# top         s1  Movie  Dick Johnson Is Dead  Unknown  Unknown  United States
# freq         1   6126                     1     2621      825           2809
#
#         date_added category  duration                     listed_in  \
# count         8790     8790      8790                          8790
# unique        1713        5       220                           513
# top     2020-01-01    Adult  1 Season  Dramas, International Movies
# freq           110     4007      1791                           362
#
#                                               description
# count                                                8790
# unique                                               8758
# top     Paranormal activity at a lush, abandoned prope...
# ...

# %% [markdown]
# #### Insights:

# %% [markdown]
# - Two different type shows in type category,Movies & TV Shows
# - All data title is different
# - Total directors 4529, most director's data is unknown
# - Total casts 7693, most cast data is unknown
# - 749 country's upload movies & TV shows
# - United states released most movies & TV shows
# - The most type released on 01-01-2020
# - 5 different categories, most data in adult category

# %% [markdown]
# # DAY 5

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# - Histogram,kde,box - numerical
# - Count,pie - categorical

# %% [markdown]
# ### Bivariate analysis

# %% [markdown]
# - Barplot - categorical vs numerical
# - Line plot(time series) and scatter

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# - Heatmap - correlation
# - Pairplot

# %% [markdown]
# ## Histogram

# %% [markdown]
# Distribution of numerical data

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df_new, x="release_year", bins=50,kde=True)
plt.title("Distribution of Release Year")
plt.xlabel ("Release Year")
plt.show()

# %%
plt.figure(figsize=(30,10))
sns.histplot(data=movie,x="duration")
plt.title("Distribution of movie")
plt.xlabel("duration")
plt.show()

# %% [markdown]
# - Peak around 90–100 minutes
# - Most movies: 80–120 minutes
# - Slight right skew (longer movies are fewer)
# - Few movies < 50 minutes
# - Very long movies (> 180 min) are rare
# - Overall moderate spread

# %%
plt.figure(figsize=(30,10))
sns.histplot(data=TV,x="duration")
plt.title("Distribution of movie")
plt.xlabel("duration")
plt.show()

# %% [markdown]
# - Peak at 1
# - Sharp drop after 1
# - Right-skewed
# - Mostly 1–4
# - Few > 6
# - Long tail to ~17

# %% [markdown]
# ## Kde plot

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data=df_new, x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel ("Release Year") 
plt.show()

# %% [markdown]
# - Very few releases before 1950
# - Slow growth from 1950–1980
# - Gradual increase after 1980
# - Rapid growth after 2000
# - Peak around 2017–2019
# - Slight drop after 2019
# - Overall upward trend over time

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data=movie, x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel ("Release Year") 
plt.show()

# %% [markdown]
# - Releases from 1940 to 1980 represent a negligible fraction of the total dataset.
# - The vast majority of content is modern, with a long, thin tail stretching back to the 1940s.
# - The highest concentration of releases occurs right before 2020.
# - Production density shifts from a flat line to an exponential climb after 2010.
# - There is a sharp decline in density immediately following the 2018–2019 peak.

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data=TV, x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel ("Release Year") 
plt.show()

# %% [markdown]
# - Very few releases before 1950
# - Slow growth from 1950–1980
# - Gradual increase after 1980
# - Rapid growth after 2000
# - Peak around 2017–2019
# - Slight drop after 2019
# - Overall upward trend over time

# %%
plt.figure(figsize=(4,4))
sns.kdeplot(data=movie, x="duration")
plt.title("Distribution of movie")
plt.xlabel ("duration")
plt.show()

# %% [markdown]
# - The graph shows the distribution of movie durations.
# - Most movies have a duration around 90–120 minutes.
# - The peak (highest point) is close to 100 minutes, meaning this is the most common duration.
# - There are very few short movies (below 60 minutes).
# - There are also few very long movies (above 180 minutes).
# - The curve is slightly right-skewed, meaning longer durations stretch out more.
# - Overall, most movies are of medium length, not too short or too long.

# %% [markdown]
# ## Box plot

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df_new, x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel ("Release Year") 
plt.show()

# %% [markdown]
# - Most values are between 2015–2020
# - Median is around 2017–2018
# - Data is highly concentrated in recent years
# - Many older years appear as outliers
# - Very few values before 2000
# - Distribution is skewed toward recent years

# %%
plt.figure(figsize=(30,10))
sns.boxplot(data=movie,x="duration")
plt.title("Distribution movie")
plt.xlabel("duration")
plt.show()

# %% [markdown]
# - The plot shows the distribution of movie durations using a box plot.
# - The middle 50% of movies (IQR) is roughly between 90 and 120 minutes.
# - The median (center line) is around 100 minutes, showing the typical movie length.
# - The whiskers extend approximately from 50 to 150 minutes, covering most data.
# - There are many outliers on both sides:
# - Very short movies (below 50 minutes)
# - Very long movies (above 150 minutes, some even above 300 minutes)
# - The distribution is slightly right-skewed, as there are more extreme long-duration outliers.
# - Most movies are concentrated in the standard length range (90–120 minutes).

# %%
plt.figure(figsize=(30,10))
sns.boxplot(data=TV,x="category",y="duration")
plt.title("Distribution TV Shows")
plt.xlabel("Category")
plt.ylabel("duration")
plt.show()

# %% [markdown]
# - The chart compares movie durations across different categories: Adult, Teen, Kids, General, and Unknown.
# - Most movies in all categories have durations between 1 to 2 hours (main concentration).
# - The median duration for all categories is quite similar, around 1–1.5 hours.
# - The spread (IQR) is also similar across categories, showing consistency in movie lengths.
# - There are many outliers in each category:
# - Some movies are much longer (up to very high values, especially in Teen).
# - The Teen category shows the highest extreme outliers, meaning some very long movies exist there.
# - The Kids category generally has slightly shorter and more consistent durations.
# - The Unknown category has the least variation, with fewer extreme values.

# %% [markdown]
# # DAY 6

# %% [markdown]
# ## Bar plot

# %%
plt.figure(figsize=(30,10)) 
sns.barplot(data=movie,y="duration",x="category") 
plt.title("Distribution of Release Year") 
plt.xlabel("Category") 
plt.ylabel("duration") 
plt.show()

# %% [markdown]
# - Duration by category
# - Teen highest
# - Kids lowest
# - Adult high
# - General medium
# - Unknown medium-high
# - Small differences
# - Easy comparison
# - Bars clearly visible
# - Similar range overall

# %%
plt.figure(figsize=(30,10)) 
sns.barplot(data= TV ,x="category",y="duration") 
plt.title("Distribution of Release Year") 
plt.xlabel("Category") 
plt.ylabel("duration") 
plt.show()

# %% [markdown]
# - Kids category has the highest average duration.
# - Unknown has the lowest mean but the largest variability (very wide error bar).
# - The other categories are fairly close, clustered between ~1.7 and ~1.9.

# %%
sns.countplot(data=df_new, x="category", hue="type")
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %% [markdown]
#  ## Line plot

# %%
year_counts = df_new["release_year"].value_counts().sort_index()

plt.figure(figsize=(6,4))
sns.lineplot(x=year_counts.index, y=year_counts.values)
plt.title("Trend of Releases Over Years")
plt.xlabel("Release Year")
plt.ylabel("Number of Releases")
plt.show()

# %% [markdown]
# - Very few releases before 1950
# - Slow increase from 1950 to 2000
# - Rapid growth after 2000
# - Sharp rise after 2015
# - Peak around 2018–2019
# - Drop after 2020
# - Overall increasing trend over time

# %%
plt.figure(figsize=(20,4)) 
sns.lineplot(data=TV,x="release_year",y="duration") 
plt.title("Distribution of Release Year") 
plt.xlabel("Category") 
plt.ylabel("duration") 
plt.show()

# %% [markdown]
# - The graph shows how movie releases are distributed over different years.
# - Very few movies were released before 1950.
# - The number of releases starts increasing after 1960.
# - There are some peaks (high points) around the 1970s and 1990s.
# - After 2000, the number of releases becomes more steady.
# - Recent years show smaller fluctuations compared to earlier years.

# %%
plt.figure(figsize=(20,4)) 
sns.lineplot(data=movie,x="release_year",y="duration") 
plt.title("Distribution of Release Year") 
plt.xlabel("Release year") 
plt.ylabel("duration") 
plt.show()

# %% [markdown]
# - The graph shows how movie duration changes over the years.
# - Movie duration increases from the 1940s to the 1960s.
# - The highest duration is around the mid-1960s.
# - After that, durations fluctuate up and down.
# - From 2000 onwards, durations become more stable.
# - Recent movies have slightly shorter and consistent durations.

# %% [markdown]
# ## Pie chart

# %%
import matplotlib.pyplot as plt

# Count occurrences of each category
counts = df_new["country"].value_counts().sort_values(ascending=False).head(10)

plt.figure(figsize=(4,4))
plt.pie(counts,labels = counts.index,  autopct='%1.1f%%')
plt.title("Distribution by Region")
plt.show()

# %% [markdown]
# - US Lead,Almost half (46.6%).
# - India is next biggest at 16.1% .
# - unknown is 13.7%
# - Top 3,total over 75% of the chart.
# - Others- Many countries with very small shares (under 7% each)

# %% [markdown]
# ## Heat map

# %%
plt.figure(figsize=(4,4))
sns.heatmap(movie.corr(numeric_only=True),annot=True,cmap="coolwarm")
plt.title("correlation heatmap") 
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.heatmap(TV.corr(numeric_only=True),annot=True,cmap="coolwarm")
plt.title("correlation heatmap") 
plt.show()

# %% [markdown]
# - No Link: Correlation is almost zero (-0.082).
# - Random: Year has no real effect on length.
# - Stable: Duration hasn't changed much over time.

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(y=movie['duration'],x=movie['release_year'])

plt.show()

# %% [markdown]
# - Huge cluster of points after 2010.
# - Modern content shows much wider range of lengths.
# - Very few points exist before 1960.
# - Length stays scattered regardless of the year.
# - Massive surge in production in the last 10 years.

# %% [markdown]
# # DAY 7

# %% [markdown]
# ## Pair plot

# %%
plt.figure(figsize=(5,6))
sns.pairplot(movie[['release_year','duration']])

# %% [markdown]
# - The pairplot shows no strong linear relationship between `release_year` and `duration`.
# - Points are scattered widely, so newer movies are not consistently longer or shorter.
# - Most movies cluster around typical durations, regardless of release year.
# - The trend is almost flat, confirming the weak negative correlation.

# %%
plt.figure(figsize=(5,6))
sns.pairplot(TV[['release_year','duration']])

# %% [markdown]
# - The graph shows the relationship between release year and movie duration.
# - Most movies are released after the year 2000, with a high concentration in recent years.
# - Very few movies are from before 1980.
# - Most movie durations are between 1 to 3 hours.
# - There are a few long-duration outliers (above 5 hours), but they are rare.
# - The scatter plot shows no strong relationship between release year and duration.
# - Movies from different years have similar duration ranges.

# %% [markdown]
# ## **CONCLUSION**

# %% [markdown]
# In this project, the Netflix Dataset was successfully cleaned and analyzed. Several changes were made to improve the quality of the data. Missing values in columns like director, cast, and country were handled by filling or removing them.The movies and tv shows are seperated to a file. The duration column was cleaned and converted into a proper numeric format, where movies are shown in minutes and TV shows in seasons.
#
# After cleaning, the dataset became more accurate and easy to use for analysis. The analysis showed that Netflix has more movies than TV shows, most content is released after 2010, and popular genres include drama and comedy. It also showed that content is mainly made for young and adult audiences.
#
# Overall, this project helped in understanding how to clean data, fix errors, and perform data analysis. It shows the importance of data preprocessing before doing any analysis.

# %% [markdown]
# ## KEY INSIGHTS

# %% [markdown]
# - Movies dominated in netflix than tv shows.
# - In the dataset 6126 Moviesand 2664 Tv shows are there.
# - Most content dominated by United States.
# - Most of the movies and tv shows target on adult audience.
# - After cleaning the dataset ,have 8790 entries.
# - The average release year is 2014.
# - The median release year is 2017.
# - The standard deviation of release year is 8.825.
# - Most of the directors are unknown.
# - Most of the cast are unknown.
# - Most of genre are drama & international movies.
# - A huge majority of the releases happened in the last 10-15 years.
# - The no.of releases started growing very fast after 2010.
# - After 2018 peak,there is a quick decline in the no.of releases in leading into 2020.
# - long trail of circles to the left shows that releases before 2005 are rare and considered outliers.
# - The highest releases count are in 2018-2019.
# - Adult is biggest rating category,so most titles are mature viewers.
# - Teen and adult categories have the longest durations.
# - Kids content is much shorter than other group.
# - Movie length increased sharply from the 1940's to the mid 1960's.
# - Some outliers very short (<50 min) and very long (>200 min) films.
# - The correlation between release year and duration is -0.21.
# - The value is close to 0,so the relationship is not strong
# - No strong linear relationship between release year and duration
# - Tv show duration are mostly 1-3 seasons- Movies dominated in netflix than tv shows.
# - In the dataset 6126 Moviesand 2664 Tv shows are there.
# - Most content dominated by United States.
# - Most of the movies and tv shows target on adult audience.
# - After cleaning the dataset ,have 8790 entries.
# - The average release year is 2014.
# - The median release year is 2017.
# - The standard deviation of release year is 8.825.
# - Most of the directors are unknown.
# - Most of the cast are unknown.
# - Most of genre are drama & international movies.
# - A huge majority of the releases happened in the last 10-15 years.
# - The no.of releases started growing very fast after 2010.
# - After 2018 peak,there is a quick decline in the no.of releases in leading into 2020.
# - long trail of circles to the left shows that releases before 2005 are rare and considered outliers.
# - The highest releases count are in 2018-2019.
# - Adult is biggest rating category,so most titles are mature viewers.
# - Teen and adult categories have the longest durations.
# - Kids content is much shorter than other group.
# - Movie length increased sharply from the 1940's to the mid 1960's.
# - Some outliers very short (<50 min) and very long (>200 min) films.
# - The correlation between release year and duration is -0.21.
# - The value is close to 0,so the relationship is not strong
# - No strong linear relationship between release year and duration
# - Tv show duration are mostly 1-3 seasons
